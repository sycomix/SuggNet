# %% [markdown]
# # preprocessing
#
# This notebook is for justifying preprocessing steps chosen in preprocessing.py script. It presents an explatory data analysis to improve the preprocessing steps.
# Here we visualize the effect of different parameters on each step using dispersion vectors (Shamlo et al., 2020)
# This notebook expect xarray dataset as an input and produce a xarray dataset of preprocessed data.
# preprocessing steps include:
#
# 1. Re-referencing
# 2. Band-pass filtering (if we apply a highpass filter but no low-pass filter does it affect the end result considering that my downstream task is time-frequency analysis so I will apply filtering at the end anyway?)
# 3. epoching
# 4. Autoreject
# 5. ICA

# %% [markdown]
# ## Setup

# %%
# Import necessary modules
import mne
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import mne_bids
from pathlib import Path
from autoreject import AutoReject
from autoreject import get_rejection_threshold 
import pyprep
from pyprep.prep_pipeline import PrepPipeline
import copy
import xarray as xr
import ast

# utility functions 

def make_montage(path='data/raw/plb-hyp-live2131111.vhdr'):
    """
    Create a montage from barin vision raw data

    Parameters
    ----------
    path : str
        path to barinvision data header file
    
    """
    raw = mne.io.read_raw_brainvision(path, verbose=False, misc=['ECG'])
    raw.set_channel_types({'ECG':'ecg'})
    ch_names = copy.deepcopy(raw.info['ch_names']) # make a deep copy of the lists of the channel names
                                                   # otherwise ecg channel will be removed in the raw object!!
    ch_names.remove('ECG')
    pos_array = raw._get_channel_positions()
    pos_dict = dict(zip(ch_names,pos_array))
    pos = mne.channels.make_dig_montage(pos_dict)
    
    return pos

def plot_psd_topomap_raw(raw, bands=None):
    
    """
    plot psd topomap for all frequency bands using welch methods. 
    raw : mne.io.Raw
    bands : dict
    """
    # Set montage
    pos = make_montage() # making montage from data position is almost the same as using BC-128.bvef
                        # only difference is that bvef does not include mastoid channels' names
    raw.set_montage(pos)
    pos = raw.get_montage() # because of eog channels, we should re-get the digitized point after we set the new montage

    # pos is an object of DigMontage type, instead we need a 2D array of XY channel postions,
    # the following will do that
    ch_pos = np.array(list(pos.get_positions()['ch_pos'].values())) 
    ch_pos = ch_pos[:,0:2]

    # creat a dictionary of the frequency bands with their lower and upper bounds
    if bands == None: # if user did not define special frequency bands, use this as defualt
        keys = ['Delta','Theta', 'Alpha', 'Beta', 'Gamma']
        bounds = [(1,4), (4,8), (8,12), (12,30), (30,45)]
        bands = dict(zip(keys, bounds))

    # psd topomap across different frequency bands
    fig, axes = plt.subplots(1, len(bands), sharex= True, figsize=(18,3.5))
    for i,key in enumerate(bands.keys()):
        psds = mne.time_frequency.psd_welch(
            raw, fmin=bands[key][0], fmax=bands[key][1], picks=['eeg'], average= 'mean', verbose=False)
        psds_mean = psds[0].mean(axis=1)
        mne.viz.plot_topomap(
            psds_mean, ch_pos, cmap='RdBu_r', axes=axes[i], outlines='head',
            show_names=True, names=raw.ch_names, show=False)
        axes[i].set_title(key, fontsize=18)

    plt.suptitle('PSD topomap (to detect bad channels)', y=1.12, fontsize=24)
    plt.show()


# %pip install memory_profiler
# %reload_ext memory_profiler
# %memit raw = cut_noisy(raw, task=task, language='hun')

# %% [markdown]
# ### Opening data and Re-referencing
# As an instance of the effect of changing the reference, we also see its effect on the frontal channels (uncomment the line of setting eeg reference to see the effect):

# %%
#### open dataset
ds = xr.open_dataset('data/dataset.nc')
#### create mne object from dataset
# info object
sub = 0
task = 'baseline'
ch_names = list(ds.coords['channels'].values)
sfreq = ds.attrs['sfreq']
info = mne.create_info(ch_names=ch_names, sfreq=sfreq, ch_types='eeg')
# mne object
data = ds[task][sub].to_numpy()
bads = ast.literal_eval(ds.attrs['bad_channels'][sub])
info['bads'] = bads
raw = mne.io.RawArray(data, info)
raw.set_channel_types(
    {'ECG':'ecg', 
    'EOG1':'eog', 
    'EOG2': 'eog'
    })

# raw.add_reference_channels(ref_channels = 'FCz') # is it for adding the reference channel to the data?
raw.set_eeg_reference(ref_channels=['M1','M2'])
pos = make_montage()
raw.set_montage(pos)
raw.plot_psd_topo(fmin=0, fmax=40)
plt.show()
# Out:
# Creating RawArray with float64 data, n_channels=61, n_times=300001
#     Range : 0 ... 300000 =      0.000 ...   300.000 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying a custom ('EEG',) reference.
# Effective window size : 2.048 (s)
# /var/folders/pn/qy0qc5tx7t7_97xjmy6pvksc0000gn/T/ipykernel_44566/3662620814.py:28: RuntimeWarning: Not setting position of 1 misc channel found in montage:
# ['ECG']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = mne.io.read_raw_brainvision(path, verbose=False, misc=['ECG'])
# /var/folders/pn/qy0qc5tx7t7_97xjmy6pvksc0000gn/T/ipykernel_44566/3662620814.py:29: RuntimeWarning: The unit for channel(s) ECG has changed from NA to V.
#   raw.set_channel_types({'ECG':'ecg'})
# /var/folders/pn/qy0qc5tx7t7_97xjmy6pvksc0000gn/T/ipykernel_44566/1532752745.py:24: RuntimeWarning: Fiducial point nasion not found, assuming identity unknown to head transformation
#   raw.set_montage(pos)
# /var/folders/pn/qy0qc5tx7t7_97xjmy6pvksc0000gn/T/ipykernel_44566/1532752745.py:24: RuntimeWarning: Not setting positions of 2 eog channels found in montage:
# ['EOG1', 'EOG2']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw.set_montage(pos)

# %% [markdown]
# ### highpass filter cutoff
# in the second iteration of preprocessing the cutoff of highpass filtering will be changed to 0.5. Different value of cutoffs (None, 0.3, 0.5, 1) applied to the baseline1 part of subject 01's eeg data. From the visulisation cutoff 1 could eliminate the majority of drift artefacts. If we don't want to go for a cut off as large as 1 Hz, the cutoff value of 0.5 was slightly better than 0.3, so we will choose 0.5Hz. Also, this is the value suggested by Mike X. cohen in his video about the preprocessing steps.
#
# to-do: lowpass filtering and its parameters.

# %% [markdown]
# ### epoching

# %%
new_annot = mne.Annotations(onset=[0],
                         duration=[int(len(raw)/sfreq)],
                        description=[task])
raw.set_annotations(new_annot)
events, event_dict = mne.events_from_annotations(raw, chunk_duration= 1)
## epoch data
epoch = mne.Epochs(raw, events, event_dict, baseline=None, preload= True)
# Out:
# Used Annotations descriptions: ['baseline']
# Not setting metadata
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 300 events and 701 original time points ...
# 1 bad epochs dropped

# %% [markdown]
# ### AutoReject
# In this part, I'll apply autoreject (global) and will compare the result with the manual rejection.

# %%
###### global rejection treshold

reject = get_rejection_threshold(epoch, decim=2)
print('The rejection dictionary is %s' % reject)
epoch.drop_bad(reject=reject)
epoch.average().plot()

###### local rejection 
# ar = AutoReject()
# epochs_clean = ar.fit_transform(epoch)
# Out:
# Estimating rejection dictionary for eeg
# Estimating rejection dictionary for eog
# The rejection dictionary is {'eeg': 0.00016315543207332808, 'eog': 0.0001824}
#     Rejecting  epoch based on EEG : ['FC3', 'FC5', 'FC6']
#     Rejecting  epoch based on EEG : ['F6', 'FC3', 'FC5', 'FC6', 'C5']
#     Rejecting  epoch based on EEG : ['C4', 'F5', 'F6', 'FC4', 'FC5', 'FC6', 'C5', 'CP6']
#     Rejecting  epoch based on EEG : ['F6', 'FC5', 'FC6', 'CP5']
#     Rejecting  epoch based on EEG : ['C3', 'F5', 'FC3', 'FC5', 'FC6', 'CP5']
#     Rejecting  epoch based on EEG : ['F4', 'C3', 'F7', 'F8', 'F5', 'F6', 'FC3', 'FC4', 'FC5', 'FC6']
#     Rejecting  epoch based on EEG : ['FC4', 'FC5', 'FC6']
#     Rejecting  epoch based on EEG : ['FC5']
#     Rejecting  epoch based on EEG : ['FC5']
#     Rejecting  epoch based on EEG : ['C3', 'C4', 'F6', 'FC3', 'FC4', 'FC5', 'FC6']
#     Rejecting  epoch based on EEG : ['F6', 'FC3', 'FC4', 'FC5', 'FC6', 'C5']
#     Rejecting  epoch based on EEG : ['FC6']
#     Rejecting  epoch based on EOG : ['EOG1']
# 13 bad epochs dropped

# %% [markdown]
# ### EOG artefact detections
# After deleting the bad parts, according to the lenght of the audio recording, first apply a highpass filter of 1 hz, then detect eog events, because it might detect small drift as eog events.
# (based on this part, we won't need ICA to remove eog or ecg artefacts)

# %%
eog_epochs = mne.preprocessing.create_eog_epochs(raw, baseline=(-0.5, -0.2))
eog_epochs.plot_image(combine='mean')
plt.savefig('eogevents.png')
plt.show()
# Out:
# Using EOG channels: EOG1, EOG2
# EOG channel index for this subject is: [26 27]
# Filtering the data to remove DC offset to help distinguish blinks from saccades
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 10000 samples (10.000 sec)
#
# Now detecting blinks and generating corresponding events
# Found 500 significant peaks
# Number of EOG events detected: 500
# Not setting metadata
# Not setting metadata
# 500 matching events found
# Applying baseline correction (mode: mean)
# Loading data for 500 events and 1001 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# Not setting metadata
# 499 matching events found
# No baseline correction applied
# 0 projection items activated
# 0 bad epochs dropped
# combining channels using "mean"

# %%
#ICA

# TEST: run ICA
import mne_bids
from xarray_creator import _cut_noisy
from preprocessing import _make_montage
from mne.preprocessing import (ICA, create_eog_epochs, create_ecg_epochs,
                               corrmap)
# open raw data

# %%
task = 'baseline1'
bids_path = mne_bids.BIDSPath(subject='02', session='01', task=task, root='data/BIDS_data')
raw = mne_bids.read_raw_bids(bids_path, extra_params={'preload':True})
raw = _cut_noisy(raw, task, 'hun')
raw.filter(1,30)  # filter before ICA
pos = _make_montage()
raw.set_montage(pos)
raw.info['bads'] = []

# create eog evoked
eog_evoked = create_eog_epochs(raw).average()
eog_evoked.apply_baseline(baseline=(None, -0.2))
eog_evoked.plot_joint()

# create ecg evoked
ecg_evoked = create_ecg_epochs(raw).average()
ecg_evoked.apply_baseline(baseline=(None, None))
ecg_evoked.plot_joint()

ica = ICA(n_components=15, max_iter='auto', random_state=42)
ica.fit(raw)

ica.exclude = []
# find which ICs match the EOG pattern
eog_indices, eog_scores = ica.find_bads_eog(raw, measure='zscore', threshold=2)
ica.exclude = eog_indices

# find which ICs match the ECG pattern
ecg_indices, ecg_scores = ica.find_bads_ecg(raw, measure='correlation',
                                            threshold=0.6)
ica.exclude = ecg_indices

# barplot of ICA component "ECG match" scores
ica.plot_scores(ecg_scores)

# plot diagnostics
if ecg_indices != []:
    print('#####################################################')
    ica.plot_properties(raw, picks=ecg_indices)

# plot ICs applied to raw data, with ECG matches highlighted
ica.plot_sources(raw, show_scrollbars=False)

# plot ICs applied to the averaged ECG epochs, with ECG matches highlighted
ica.plot_sources(ecg_evoked)


# barplot of ICA component "EOG match" scores
ica.plot_scores(eog_scores)

# plot diagnostics
if ecg_indices != []:
    print('#####################################################')
    ica.plot_properties(raw, picks=eog_indices)

# plot ICs applied to raw data, with EOG matches highlighted
ica.plot_sources(raw, show_scrollbars=False)

# plot ICs applied to the averaged EOG epochs, with EOG matches highlighted
ica.plot_sources(eog_evoked)

ica.exclude = [0]  # indices chosen based on various plots above
# ica.apply() changes the Raw object in-place, so let's make a copy first:
reconst_raw = raw.copy()
ica.apply(reconst_raw, exclude=ica.exclude)

raw.plot( n_channels=61,
         show_scrollbars=False)
reconst_raw.plot(n_channels=61,
                 show_scrollbars=False)
del reconst_raw

ica.plot_overlay(raw, exclude=[0], picks='eeg')

ica.plot_components()


# in the logger we will have
exclude = [0,  # blinks
           2  # saccades
           ]

# plot ICs applied to the averaged EOG epochs, with EOG matches highlighted
eog_evoked = mne.preprocessing.create_eog_epochs(raw_filt).average()
eog_evoked.apply_baseline(baseline=(None, None))
eog_evoked.plot_joint()
ica.plot_sources(eog_evoked)

ica.plot_components(exclude)
ica.exclude = exclude
